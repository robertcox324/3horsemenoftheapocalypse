# %% [markdown]
# # Case Study: Movie Data Analysis
#
# This notebook uses a dataset from the MovieLens website.
#
# * Data SourceL MovieLens web site (filename: ml-20m.zip)
# * Location https://grouplens.org/datasets/movielens
#
#
# First Let's explore the folder to see what files we have in the dataset

# %%
# !ls -la ./movielens
# Out:
# total 855092
# drwxr-xr-x 1 aydin 197609         0 Mar  5 23:15 .
# drwxr-xr-x 1 aydin 197609         0 Mar  8 03:05 ..
# -rw-r--r-- 1 aydin 197609 323544381 Jan  3 23:41 genome-scores.csv
# -rw-r--r-- 1 aydin 197609     18103 Jan  3 23:41 genome-tags.csv
# -rw-r--r-- 1 aydin 197609    570090 Jan  3 23:41 links.csv
# -rw-r--r-- 1 aydin 197609   1397542 Jan  3 23:41 movies.csv
# -rw-r--r-- 1 aydin 197609 533444411 Jan  3 23:41 ratings.csv
# -rw-r--r-- 1 aydin 197609     10261 Jan  3 23:41 README.txt
# -rw-r--r-- 1 aydin 197609  16603996 Jan  3 23:41 tags.csv

# %% [markdown]
# # Use Pandas to read data
#
# In this notebook, we will be using three CSV files:
#
# * ratings.csv: userId, movieId, rating, timestamp
# * tags.csv: userId, movieId, tag, timestamp
# * movies.csv: movieId, title, genres

# %%
import pandas as pd

# %%
movie_data = pd.read_csv('./movielens/movies.csv', sep=',')

# %%
movie_data.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#Timestamps represent seconds since midnight Coordinated Universal Time (UTC)
tags = pd.read_csv('./movielens/tags.csv', sep=",")
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
ratings = pd.read_csv('./movielens/ratings.csv', sep=",")
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %% [markdown]
# ### We do not need timestamp column right now but we will get back to it later on.

# %%
del ratings['timestamp']
del tags['timestamp']

# %% [markdown]
# # Descriptive Statistics

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %%
ratings['rating'].min(), ratings['rating'].max(), ratings['rating'].std()
# Out:
# (0.5, 5.0, 1.0519889192942424)

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# dtype: float64

# %% [markdown]
# ## Quick sanity check
#
# Here we are verifying adequacy of ratings by checking if there are any ratings greater than 5 or less than 0. It is unneccessary since we know min and max ratings values but this is an alternative way.

# %%
filter_1 = ratings['rating'] > 5

# %%
filter_1.any()
# Out:
# False

# %%
filter_2 = ratings['rating'] > 0

# %%
filter_2.all()
# Out:
# True

# %% [markdown]
# # Data Cleaning: Handling missing data

# %%
movie_data.shape
# Out:
# (27278, 3)

# %%
movie_data.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags.shape
# Out:
# (465564, 3)

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
null_ = tags['tag'].isnull()
null_
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 465559    False
# 465560    False
# 465561    False
# 465562    False
# 465563    False
# Name: tag, Length: 465564, dtype: bool

# %%
null_tags = tags[null_]
null_tags
# Out:
#         userId  movieId  tag
# 373276  116460      123  NaN
# 373277  116460      346  NaN
# 373281  116460     1184  NaN
# 373288  116460     1785  NaN
# 373289  116460     2194  NaN
# 373291  116460     2691  NaN
# 373299  116460     4103  NaN
# 373301  116460     4473  NaN
# 373303  116460     4616  NaN
# 373319  116460     7624  NaN
# 373325  116460     8898  NaN
# 373332  116460    32460  NaN
# 373334  116460    33826  NaN
# 373339  116460    36537  NaN
# 373340  116460    55805  NaN
# 454615  133634    33826  NaN

# %%
null_tag_movies = null_tags['movieId']
pd.DataFrame(movie_data, index=null_tag_movies)
# Out:
#          movieId                                              title  \
# movieId
# 123        125.0                      Flirting With Disaster (1996)
# 346        350.0                                 Client, The (1994)
# 1184      1210.0  Star Wars: Episode VI - Return of the Jedi (1983)
# 1785      1869.0                                   Black Dog (1998)
# 2194      2279.0                                Urban Legend (1998)
# 2691      2777.0                                       Cobra (1925)
# 4103      4197.0                                   Real Life (1979)
# 4473      4568.0                            Best of the Best (1989)
# 4616      4711.0             Theremin: An Electronic Odyssey (1993)
# 7624      8024.0                      Thing Called Love, The (1993)
# 8898     26523.0                  Silent Night, Deadly Night (1984)
# 32460        NaN                                                NaN
# 33826        NaN                                                NaN
# 36537        NaN                                                NaN
# 55805        NaN                                                NaN
# 33826        NaN                                                NaN
#
#                           genres
# movieId
# 123                       Comedy
# 346       Drama|Mystery|Thriller
# 1184     Action|Adventure|Sci-Fi
# 1785             Action|Thriller
# 2194             Horror|Thriller
# 2691                       Drama
# 4103                      Comedy
# 4473                      Action
# 4616                 Documentary
# 7624        Comedy|Drama|Romance
# 8898             Horror|Thriller
# 32460                        NaN
# 33826                        NaN
# 36537                        NaN
# 55805                        NaN
# 33826                        NaN

# %% [markdown]
# ### Since we have null values for tags, let's drop them to have a cleaner dataset

# %%
tags = tags.dropna()

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
tags.shape
# Out:
# (465548, 3)

# %% [markdown]
# ### Extract year from title e.g (1995)

# %%
movie_data['year'] = movie_data['title'].str.extract(".*\((.*)\).*", expand=True)

# %%
movie_data.tail()
# Out:
#        movieId                          title                    genres  year
# 27273   131254   Kein Bund für's Leben (2007)                    Comedy  2007
# 27274   131256  Feuer, Eis & Dosenbier (2002)                    Comedy  2002
# 27275   131258             The Pirates (2014)                 Adventure  2014
# 27276   131260            Rentun Ruusu (2001)        (no genres listed)  2001
# 27277   131262               Innocence (2014)  Adventure|Fantasy|Horror  2014

# %% [markdown]
# # Merge Data - average movie ratings over time

# %%
average_rating = ratings[['movieId', 'rating']].groupby('movieId', as_index=False).mean()
average_rating.tail()
# Out:
#        movieId  rating
# 26739   131254     4.0
# 26740   131256     4.0
# 26741   131258     2.5
# 26742   131260     3.0
# 26743   131262     4.0

# %%
joined = movie_data.merge(average_rating, on='movieId', how='inner')
joined.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995  3.921240
# 1                   Adventure|Children|Fantasy  1995  3.211977
# 2                               Comedy|Romance  1995  3.151040
# 3                         Comedy|Drama|Romance  1995  2.861393
# 4                                       Comedy  1995  3.064592

# %%
joined.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995  3.921240
# 1                   Adventure|Children|Fantasy  1995  3.211977
# 2                               Comedy|Romance  1995  3.151040
# 3                         Comedy|Drama|Romance  1995  2.861393
# 4                                       Comedy  1995  3.064592

# %% [markdown]
# ## Specify Data to be used in Twitter API request

# %%
rating_mask = joined.rating  > 4
year_mask = joined.year > '1990'
genre_mask = joined.genres.str.contains("Fantasy") | joined.genres.str.contains("Animation")

# %%
final_data = joined[rating_mask & year_mask & genre_mask]
final_data = final_data.reset_index().drop(columns='index')

# %%
import numpy as np
titles = np.array(final_data.title)
for index, title in np.ndenumerate(titles):
    final_data.loc[index, 'title'] = title.split("(")[0]
final_data
# Out:
#     movieId                                              title  \
# 0       720   Wallace & Gromit: The Best of Aardman Animation
# 1       745                   Wallace & Gromit: A Close Shave
# 2      1148              Wallace & Gromit: The Wrong Trousers
# 3      3000                                 Princess Mononoke
# 4      4993  Lord of the Rings: The Fellowship of the Ring,...
# 5      5618                                     Spirited Away
# 6      5952            Lord of the Rings: The Two Towers, The
# 7      7153    Lord of the Rings: The Return of the King, The
# 8     26718                                  Life On A String
# 9     27328                                            Monday
# 10    31658                              Howl's Moving Castle
# 11    48394                                   Pan's Labyrinth
# 12    60069                                            WALL·E
# 13    61240                              Let the Right One In
# 14    62336                                              FLCL
# 15    68954                                                Up
# 16    73365                                   Dead Time: Kala
# 17    76093                          How to Train Your Dragon
# 18    78499                                       Toy Story 3
# 19    95177                                            Alcina
# 20    96608                                     Runaway Brain
# 21    96935                           My Left Eye Sees Ghosts
# 22    97300                                    Björk: Volumen
# 23    97789                                Step Up Love Story
# 24    98241                               Starry starry night
# 25   102477               Tales of Vesperia: The First Strike
# 26   105191                                      Rocaterrania
# 27   108466                                 Curse of the Ring
# 28   108979                                      Cowboy Bebop
# 29   110097                                   From Dad to Son
# 30   111783                                         Neverland
# 31   113045                                            Boogie
# 32   114931                                           Benigni
# 33   116215            Ultramarines: A Warhammer 40,000 Movie
# 34   119161                             Beyond the Mind's Eye
# 35   128362                                   Burn Paris Burn
# 36   128987                                           Lascars
# 37   128991                                    Johnny Express
# 38   129307                                            Wu yen
# 39   130034                              Stand by Me Doraemon
# 40   130644  The Garden of Sinners - Chapter 5: Paradox Par...
# 41   130996                               The Beautiful Story
#
#                                               genres  year    rating
# 0                         Adventure|Animation|Comedy  1996  4.109473
# 1                          Animation|Children|Comedy  1995  4.167315
# 2                    Animation|Children|Comedy|Crime  1993  4.181068
# 3           Action|Adventure|Animation|Drama|Fantasy  1997  4.096299
# 4                                  Adventure|Fantasy  2001  4.137925
# 5                        Adventure|Animation|Fantasy  2001  4.203810
# 6                                  Adventure|Fantasy  2002  4.107521
# 7                     Action|Adventure|Drama|Fantasy  2003  4.142382
# 8                    Adventure|Drama|Fantasy|Musical  1991  5.000000
# 9               Action|Comedy|Crime|Fantasy|Thriller  2000  4.500000
# 10               Adventure|Animation|Fantasy|Romance  2004  4.066078
# 11                            Drama|Fantasy|Thriller  2006  4.037898
# 12       Adventure|Animation|Children|Romance|Sci-Fi  2008  4.038929
# 13                      Drama|Fantasy|Horror|Romance  2008  4.010526
# 14                   Animation|Comedy|Fantasy|Sci-Fi  2000  4.006627
# 15                Adventure|Animation|Children|Drama  2009  4.038266
# 16                  Crime|Fantasy|Film-Noir|Thriller  2007  4.500000
# 17         Adventure|Animation|Children|Fantasy|IMAX  2010  4.000420
# 18  Adventure|Animation|Children|Comedy|Fantasy|IMAX  2010  4.012974
# 19                             Drama|Fantasy|Romance  2000  4.250000
# 20                           Animation|Comedy|Sci-Fi  1995  4.142857
# 21                            Comedy|Fantasy|Romance  2002  4.333333
# 22                                 Animation|Musical  1999  4.125000
# 23                          Animation|Comedy|Romance  2002  4.750000
# 24                            Children|Drama|Fantasy  2011  4.166667
# 25                                         Animation  2009  4.250000
# 26                               Documentary|Fantasy  2009  5.000000
# 27                    Action|Adventure|Drama|Fantasy  2004  4.500000
# 28           Action|Adventure|Animation|Crime|Sci-Fi  1998  4.042373
# 29                                   Animation|Drama  2012  4.500000
# 30                                 Adventure|Fantasy  2011  4.214286
# 31                            Action|Animation|Crime  2009  4.500000
# 32                            Animation|Comedy|Drama  2009  4.500000
# 33                                  Animation|Sci-Fi  2010  4.500000
# 34                                  Animation|Comedy  1992  4.250000
# 35                         Animation|Fantasy|Mystery  2009  4.500000
# 36                                  Animation|Comedy  2009  4.500000
# 37                           Animation|Comedy|Sci-Fi  2014  4.375000
# 38                                    Comedy|Fantasy  2001  4.500000
# 39                  Animation|Children|Drama|Fantasy  2014  4.500000
# 40                                         Animation  2008  5.000000
# 41                           Adventure|Drama|Fantasy  1992  5.000000

# %%
import numpy as np
final_data = final_data.drop(final_data[final_data.title.str.contains(", The")].index, inplace = False)
final_data = final_data.reset_index().drop(columns='index')
titles = np.array(final_data.title)
for index, title in np.ndenumerate(titles):
    final_data.loc[index, 'hashtags'] = "#" +  title.replace(" ", "")

# %%
final_data
# Out:
#     movieId                                              title  \
# 0       720   Wallace & Gromit: The Best of Aardman Animation
# 1       745                   Wallace & Gromit: A Close Shave
# 2      1148              Wallace & Gromit: The Wrong Trousers
# 3      3000                                 Princess Mononoke
# 4      5618                                     Spirited Away
# 5     26718                                  Life On A String
# 6     27328                                            Monday
# 7     31658                              Howl's Moving Castle
# 8     48394                                   Pan's Labyrinth
# 9     60069                                            WALL·E
# 10    61240                              Let the Right One In
# 11    62336                                              FLCL
# 12    68954                                                Up
# 13    73365                                   Dead Time: Kala
# 14    76093                          How to Train Your Dragon
# 15    78499                                       Toy Story 3
# 16    95177                                            Alcina
# 17    96608                                     Runaway Brain
# 18    96935                           My Left Eye Sees Ghosts
# 19    97300                                    Björk: Volumen
# 20    97789                                Step Up Love Story
# 21    98241                               Starry starry night
# 22   102477               Tales of Vesperia: The First Strike
# 23   105191                                      Rocaterrania
# 24   108466                                 Curse of the Ring
# 25   108979                                      Cowboy Bebop
# 26   110097                                   From Dad to Son
# 27   111783                                         Neverland
# 28   113045                                            Boogie
# 29   114931                                           Benigni
# 30   116215            Ultramarines: A Warhammer 40,000 Movie
# 31   119161                             Beyond the Mind's Eye
# 32   128362                                   Burn Paris Burn
# 33   128987                                           Lascars
# 34   128991                                    Johnny Express
# 35   129307                                            Wu yen
# 36   130034                              Stand by Me Doraemon
# 37   130644  The Garden of Sinners - Chapter 5: Paradox Par...
# 38   130996                               The Beautiful Story
#
#                                               genres  year    rating  \
# 0                         Adventure|Animation|Comedy  1996  4.109473
# 1                          Animation|Children|Comedy  1995  4.167315
# 2                    Animation|Children|Comedy|Crime  1993  4.181068
# 3           Action|Adventure|Animation|Drama|Fantasy  1997  4.096299
# 4                        Adventure|Animation|Fantasy  2001  4.203810
# 5                    Adventure|Drama|Fantasy|Musical  1991  5.000000
# 6               Action|Comedy|Crime|Fantasy|Thriller  2000  4.500000
# 7                Adventure|Animation|Fantasy|Romance  2004  4.066078
# 8                             Drama|Fantasy|Thriller  2006  4.037898
# 9        Adventure|Animation|Children|Romance|Sci-Fi  2008  4.038929
# 10                      Drama|Fantasy|Horror|Romance  2008  4.010526
# 11                   Animation|Comedy|Fantasy|Sci-Fi  2000  4.006627
# 12                Adventure|Animation|Children|Drama  2009  4.038266
# 13                  Crime|Fantasy|Film-Noir|Thriller  2007  4.500000
# 14         Adventure|Animation|Children|Fantasy|IMAX  2010  4.000420
# 15  Adventure|Animation|Children|Comedy|Fantasy|IMAX  2010  4.012974
# 16                             Drama|Fantasy|Romance  2000  4.250000
# 17                           Animation|Comedy|Sci-Fi  1995  4.142857
# 18                            Comedy|Fantasy|Romance  2002  4.333333
# 19                                 Animation|Musical  1999  4.125000
# 20                          Animation|Comedy|Romance  2002  4.750000
# 21                            Children|Drama|Fantasy  2011  4.166667
# 22                                         Animation  2009  4.250000
# 23                               Documentary|Fantasy  2009  5.000000
# 24                    Action|Adventure|Drama|Fantasy  2004  4.500000
# 25           Action|Adventure|Animation|Crime|Sci-Fi  1998  4.042373
# 26                                   Animation|Drama  2012  4.500000
# 27                                 Adventure|Fantasy  2011  4.214286
# 28                            Action|Animation|Crime  2009  4.500000
# 29                            Animation|Comedy|Drama  2009  4.500000
# 30                                  Animation|Sci-Fi  2010  4.500000
# 31                                  Animation|Comedy  1992  4.250000
# 32                         Animation|Fantasy|Mystery  2009  4.500000
# 33                                  Animation|Comedy  2009  4.500000
# 34                           Animation|Comedy|Sci-Fi  2014  4.375000
# 35                                    Comedy|Fantasy  2001  4.500000
# 36                  Animation|Children|Drama|Fantasy  2014  4.500000
# 37                                         Animation  2008  5.000000
# 38                           Adventure|Drama|Fantasy  1992  5.000000
#
#                                         hashtags
# 0      #Wallace&Gromit:TheBestofAardmanAnimation
# 1                    #Wallace&Gromit:ACloseShave
# 2               #Wallace&Gromit:TheWrongTrousers
# 3                              #PrincessMononoke
# 4                                  #SpiritedAway
# 5                                 #LifeOnAString
# 6                                        #Monday
# 7                            #Howl'sMovingCastle
# 8                                #Pan'sLabyrinth
# 9                                        #WALL·E
# 10                             #LettheRightOneIn
# 11                                         #FLCL
# 12                                           #Up
# 13                                #DeadTime:Kala
# 14                         #HowtoTrainYourDragon
# 15                                    #ToyStory3
# 16                                       #Alcina
# 17                                 #RunawayBrain
# 18                          #MyLeftEyeSeesGhosts
# 19                                #Björk:Volumen
# 20                              #StepUpLoveStory
# 21                            #Starrystarrynight
# 22               #TalesofVesperia:TheFirstStrike
# 23                                 #Rocaterrania
# 24                               #CurseoftheRing
# 25                                  #CowboyBebop
# 26                                 #FromDadtoSon
# 27                                    #Neverland
# 28                                       #Boogie
# 29                                      #Benigni
# 30           #Ultramarines:AWarhammer40,000Movie
# 31                           #BeyondtheMind'sEye
# 32                                #BurnParisBurn
# 33                                      #Lascars
# 34                                #JohnnyExpress
# 35                                        #Wuyen
# 36                            #StandbyMeDoraemon
# 37  #TheGardenofSinners-Chapter5:ParadoxParadigm
# 38                            #TheBeautifulStory

# %% [markdown]
# # Twitter API access

# %%
# Dependencies

import os
import tweepy as tw
import json
from pprint import pprint
import config

# %%
auth = tw.OAuthHandler(config.consumer_key, config.consumer_secret)
auth.set_access_token(config.access_token, config.access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# if not os.path.exists('secret_twitter_credentials.pkl'):
#     Twitter={}
#     Twitter['Consumer Key'] = config.consumer_key
#     Twitter['Consumer Secret'] = config.consumer_secret
#     Twitter['Access Token'] = config.access_token
#     Twitter['Access Token Secret'] = config.access_token_secret
#     with open('secret_twitter_credentials.pkl','wb') as f:
#         pickle.dump(Twitter, f)
# else:
#     Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %%
# import twitter

# auth = twitter.oauth.OAuth(Twitter['Access Token'],
#                            Twitter['Access Token Secret'],
#                            Twitter['Consumer Key'],
#                            Twitter['Consumer Secret'])

# twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# ### Where on Earth ID number.. this helps to find location based on ID
#
# This was not needed since we found different way to pull data from twitter but still nice to have for future references

# %%
# WORLD_WOE_ID = 1
# US_WOE_ID = 23424977
# LOCAL_WOE_ID=2357024 # Atlanta WOEID

# %%
# world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
# us_trends = twitter_api.trends.place(_id=US_WOE_ID)
# local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
def twitter_pull(hash):
    users_and_text = {}
    tweet_list = ''
    tweets = tw.Cursor(api.search,
        q=hash,
            lang="en").items(1)
    for tweet in tweets:
        users_and_text["hashtag"] = hash
        users_and_text["user_name"] = tweet.user.screen_name
        users_and_text["tweet"] = tweet.text
        users_and_text["location"] = tweet.user.location
#     users_and_text = [[tweet.user.screen_name, tweet.text, tweet.user.location] for tweet in tweets]
    return users_and_text

# %%
twits = []
for hash in final_data.hashtags:
    twits.append(twitter_pull(hash))

# %%
for tweet in twits:
    print(tweet)
# Out:
# {}
# {}
# {}
# {'hashtag': '#PrincessMononoke', 'user_name': 'Mousawii_', 'tweet': 'I rated #PrincessMononoke 7.2/10\n#Mousawii_M\nhttps://t.co/b3RcTW0mmg', 'location': 'DARK'}
# {'hashtag': '#SpiritedAway', 'user_name': 'RodriguezDecann', 'tweet': 'Session 2 pleaseeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee! \n#SpiritedAway https://t.co/TM2LayzZud', 'location': 'Rizal, Calabarzon'}
# {}
# {'hashtag': '#Monday', 'user_name': 'dcbat', 'tweet': 'RT @dcbat: Will the #UnitedStates elect a woman president in your lifetime?\n\n#SundayAfternoon #SundayMotivation #SundayThoughts #SundayFeel…', 'location': 'Washington DC'}
# {'hashtag': "#Howl'sMovingCastle", 'user_name': 'CamJamClassic', 'tweet': 'HOWL howl’s moving castle... the fashion. the earrings. the turning into a bigass bird. mr smovingcastle i have fee… https://t.co/Oo4GmcZooI', 'location': 'Illinois, USA'}
# {}
# {'hashtag': '#WALL·E', 'user_name': 'cinafilm', 'tweet': 'WALL·E (2008) - Read 970 Movie Reviews \nLink: https://t.co/pcCufXL12c \n#WALL·E', 'location': 'Birmingham, England'}
# {'hashtag': '#LettheRightOneIn', 'user_name': 'MawriterIa', 'tweet': 'Best #Vampire attack scene in a movie?\n\nLost Boys is good but the reverse Jaws swimming pool attack in the original… https://t.co/cZi3fEWxFF', 'location': 'UK'}
# {'hashtag': '#FLCL', 'user_name': 'KengoMark', 'tweet': 'Start&gt;Finish More robots busts #FLCL https://t.co/0eQoCHsGYm', 'location': ''}
# {'hashtag': '#Up', 'user_name': 'andreaowenss', 'tweet': 'Superb cake.... Boy did good 😍 #takethat #Up cake for days and days https://t.co/sYsTLJ5m0C', 'location': 'Belfast, Northern Ireland'}
# {}
# {'hashtag': '#HowtoTrainYourDragon', 'user_name': 'cinafilm', 'tweet': 'How to Train Your Dragon (2010) - Read 1,054 Movie Reviews \nLink: https://t.co/h5qOxHTIxb \n#HowToTrainYourDragon', 'location': 'Birmingham, England'}
# {'hashtag': '#ToyStory3', 'user_name': 'TheLastPirateLA', 'tweet': '🤣😂🤣🤣🤣🤣🤣🤣 Spanish Buzz Light Year #ToyStory3', 'location': '#DTLA 🍀🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f🎩'}
# {'hashtag': '#Alcina', 'user_name': 'maireflavin', 'tweet': 'I will be doing an #instagramtakeover @Opera_North for our Photoshoot for #ONAlcina tomorrow so please do follow al… https://t.co/8qkhKt6Efk', 'location': ''}
# {}
# {}
# {}
# {}
# {'hashtag': '#Starrystarrynight', 'user_name': 'ktwdwdwd', 'tweet': 'Star shower.\n.\n10sec, F3.5, ISO1250, 12mm, Livecomp.\nhttps://t.co/tsNTlP9kEa\n.\n.\n#igersjp #smugmug #livecomposite… https://t.co/SEba9k9DiT', 'location': '日本 京都'}
# {}
# {}
# {}
# {'hashtag': '#CowboyBebop', 'user_name': 'menscave7', 'tweet': 'RT @menscave7: CHeck out Mens Sweaters Jackets Hoodies Vintage + New SALE \nhttps://t.co/2PXcPKONlU \n#cowboys #CowboysNation #cowboybebop #K…', 'location': ''}
# {}
# {'hashtag': '#Neverland', 'user_name': 'HanaREV1', 'tweet': 'RT @duckie_le: So I found the photo long time ago and thought it looks funny so decided to make a quicksketch, then forgot about it until t…', 'location': 'Mecklenburg-West Pomerania'}
# {'hashtag': '#Boogie', 'user_name': 'IAMKENJOURNEY', 'tweet': 'This My Real Brother Blood No Needed #Day1 #Boogie darealroadrunnerboogie.            #HappyBirthdayChamp @ Buffalo… https://t.co/2HremTalty', 'location': 'Buffalo, NY'}
# {'hashtag': '#Benigni', 'user_name': 'jeevitha2priya', 'tweet': 'Life is beautiful   #moves #benigni #life https://t.co/1avKC4Volx', 'location': ''}
# {}
# {}
# {}
# {}
# {}
# {}
# {'hashtag': '#StandbyMeDoraemon', 'user_name': 'tm4ish', 'tweet': 'me while I am watching #StandByMeDoraemon https://t.co/DK7W60PK5f', 'location': 'Leipzig, Germany'}
# {}
# {}

# %%
for index, _dict in enumerate(twits):
    if bool(_dict):
        final_data.loc[index, 'user_name'] = _dict['user_name']
        final_data.loc[index, 'tweet'] = _dict['tweet']
        final_data.loc[index, 'location'] = _dict['location']
    else:
        final_data.loc[index, 'user_name'] = None
        final_data.loc[index, 'tweet'] = None
        final_data.loc[index, 'location'] = None

# %%
final_data = final_data.dropna()

# %%
final_data.head(16)
# Out:
#     movieId                      title  \
# 3      3000         Princess Mononoke
# 4      5618             Spirited Away
# 6     27328                    Monday
# 7     31658      Howl's Moving Castle
# 9     60069                    WALL·E
# 10    61240      Let the Right One In
# 11    62336                      FLCL
# 12    68954                        Up
# 14    76093  How to Train Your Dragon
# 15    78499               Toy Story 3
# 16    95177                    Alcina
# 21    98241       Starry starry night
# 25   108979              Cowboy Bebop
# 27   111783                 Neverland
# 28   113045                    Boogie
# 29   114931                   Benigni
#
#                                               genres  year    rating  \
# 3           Action|Adventure|Animation|Drama|Fantasy  1997  4.096299
# 4                        Adventure|Animation|Fantasy  2001  4.203810
# 6               Action|Comedy|Crime|Fantasy|Thriller  2000  4.500000
# 7                Adventure|Animation|Fantasy|Romance  2004  4.066078
# 9        Adventure|Animation|Children|Romance|Sci-Fi  2008  4.038929
# 10                      Drama|Fantasy|Horror|Romance  2008  4.010526
# 11                   Animation|Comedy|Fantasy|Sci-Fi  2000  4.006627
# 12                Adventure|Animation|Children|Drama  2009  4.038266
# 14         Adventure|Animation|Children|Fantasy|IMAX  2010  4.000420
# 15  Adventure|Animation|Children|Comedy|Fantasy|IMAX  2010  4.012974
# 16                             Drama|Fantasy|Romance  2000  4.250000
# 21                            Children|Drama|Fantasy  2011  4.166667
# 25           Action|Adventure|Animation|Crime|Sci-Fi  1998  4.042373
# 27                                 Adventure|Fantasy  2011  4.214286
# 28                            Action|Animation|Crime  2009  4.500000
# 29                            Animation|Comedy|Drama  2009  4.500000
#
#                  hashtags        user_name  \
# 3       #PrincessMononoke        Mousawii_
# 4           #SpiritedAway  RodriguezDecann
# 6                 #Monday            dcbat
# 7     #Howl'sMovingCastle    CamJamClassic
# 9                 #WALL·E         cinafilm
# 10      #LettheRightOneIn       MawriterIa
# 11                  #FLCL        KengoMark
# 12                    #Up     andreaowenss
# 14  #HowtoTrainYourDragon         cinafilm
# 15             #ToyStory3  TheLastPirateLA
# 16                #Alcina      maireflavin
# 21     #Starrystarrynight         ktwdwdwd
# 25           #CowboyBebop        menscave7
# 27             #Neverland         HanaREV1
# 28                #Boogie    IAMKENJOURNEY
# 29               #Benigni   jeevitha2priya
#
#                                                 tweet  \
# 3   I rated #PrincessMononoke 7.2/10\n#Mousawii_M\...
# 4   Session 2 pleaseeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# 6   RT @dcbat: Will the #UnitedStates elect a woma...
# 7   HOWL howl’s moving castle... the fashion. the ...
# 9   WALL·E (2008) - Read 970 Movie Reviews \nLink:...
# 10  Best #Vampire attack scene in a movie?\n\nLost...
# 11  Start&gt;Finish More robots busts #FLCL https:...
# 12  Superb cake.... Boy did good 😍 #takethat #Up c...
# 14  How to Train Your Dragon (2010) - Read 1,054 M...
# 15        🤣😂🤣🤣🤣🤣🤣🤣 Spanish Buzz Light Year #ToyStory3
# 16  I will be doing an #instagramtakeover @Opera_N...
# 21  Star shower.\n.\n10sec, F3.5, ISO1250, 12mm, L...
# 25  RT @menscave7: CHeck out Mens Sweaters Jackets...
# 27  RT @duckie_le: So I found the photo long time ...
# 28  This My Real Brother Blood No Needed #Day1 #Bo...
# 29  Life is beautiful   #moves #benigni #life http...
#
#                       location
# 3                         DARK
# 4            Rizal, Calabarzon
# 6                Washington DC
# 7                Illinois, USA
# 9          Birmingham, England
# 10                          UK
# 11
# 12   Belfast, Northern Ireland
# 14         Birmingham, England
# 15             #DTLA 🍀🏴󠁧󠁢󠁳󠁣󠁴󠁿🎩
# 16
# 21                       日本 京都
# 25
# 27  Mecklenburg-West Pomerania
# 28                 Buffalo, NY
# 29
